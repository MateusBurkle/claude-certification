# %% [markdown]
# # Install Dependencies

# %%
# %pip install anthropic python-dotenv

# %% [markdown]
# # load env variables

# %%
from dotenv import load_dotenv
load_dotenv()

# %% [markdown]
# # Create API Client

# %%
from anthropic import Anthropic
client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %% [markdown]
# # Make a request - Multi-Tern Conversation 4
# ## Now We are gonna add Multi-Tern Conversation
# 1. First delete message input typed down here
# 2. Create `function` called add_user_message(messages,text):
# 3. Create `function` called add_assistant_message(message,text):
# 4. Create `function` called chat(messages):

# %%
def add_user_message(messages,text):
    user_message = {"role":"user", "content":text}
    messages.append(user_message)

def add_assistant_message(messages,text):
    assistant_message = {"role":"assistant","content":text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model = model,
        max_tokens= 1000,
        messages = messages
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add initial user question
add_user_message(messages,"Define quantum computing in one sentence")

# Get Claude's answer
answer = chat(messages)

# Add Claude's Response to the conversation history
add_assistant_message(messages,answer)

# Add User's follow up question 
add_user_message(messages,"Write other sentence")

# Get follow up response with full context 
final_answer = chat(messages)
final_answer

# %% [markdown]
# # Chat Exercise - 5
# ## Do a Exercise about claude assistant respond about something in input

# %%
messages = []

while True:
    user_input = input("Ask somenthing: ")
    print(user_input)

    add_user_message(messages,user_input)

    
    answer = chat(messages)

    add_assistant_message(messages,answer)

    print("---")

    print(answer)
