# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text.strip())

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only Python, JSON or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
import re 
import ast 

def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0

def validate_python(text):
    try: 
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0 

def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10 
    except re.error:
        return 0 


def grade_syntax(response,test_case):
    format = test_case["format"]
    
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Step 2 
# Create a function run_test_case

def run_test_case(test_case):
    """
    Calls run_prompt, then grade the results 
    """
    output = run_prompt(test_case)

    grade = grade_by_model(test_case, output)

    # Changed from score to model_score
    model_score = grade["score"]
    reasoning = grade["reasoning"]

    syntax_score = grade_syntax(output,test_case)

    score = (model_score + syntax_score) / 2 

    return {
        "output":output,
        "test_case":test_case,
        "score": score,
        "reasoning":reasoning
    }

# %%
from statistics import mean 

def run_eval(dataset):

    results = []

    for test_case in dataset:
        result = run_test_case(test_case)

        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"average score: {average_score}")
    
    return results

# %%
with open ("dataset.json","r") as f:
    dataset = json.load(f)

    results = run_eval(dataset)
# Out:
# average score: 4.5

# %%
print(json.dumps(results,indent=2))
# Out:
# [
#   {
#     "output": "```python\nimport re\nimport json\nimport sys\n\ndef extract_s3_buckets(text):\n    # Pattern for S3 bucket names in CloudFormation templates\n    patterns = [\n        r'[\"\\']?([a-z0-9][a-z0-9\\-\\.]*[a-z0-9])[\"\\']?\\s*:\\s*{\\s*\"Type\"\\s*:\\s*\"AWS::S3::Bucket\"',\n        r'\"BucketName\"\\s*:\\s*\"([a-z0-9][a-z0-9\\-\\.]*[a-z0-9])\"',\n        r'Bucket[\"\\']?\\s*:\\s*[\"\\']([a-z0-9][a-z0-9\\-\\.]*[a-z0-9])[\"\\']',\n        r's3://([a-z0-9][a-z0-9\\-\\.]*[a-z0-9])',\n    ]\n    \n    buckets = set()\n    for pattern in patterns:\n        matches = re.findall(pattern, text, re.IGNORECASE)\n        buckets.update(matches)\n    \n    return sorted(list(buckets))\n\nif __name__ == \"__main__\":\n    input_text = sys.stdin.read()\n    result = extract_s3_buckets(input_text)\n    print(json.dumps(result))\n```",
#     "test_case": {
#       "task": "Extract all AWS S3 bucket names from CloudFormation template output text",
#       "format": "regex"
#     },
#     "score": 7.0,
#     "reasoning": "The solution addresses the core task but relies on fragile regex pattern matching that will miss many real-world CloudFormation patterns. A more robust approach would parse CloudFormation templates as structured data (YAML/JSON) and traverse the resource definitions systematically, extracting bucket names from Properties.BucketName and tracking Ref/GetAtt references. The current regex-based approach is brittle and will have poor recall on typical CloudFormation templates."
#   },
#   {
#     "output": "\n```python\nimport json\nimport sys\n\ndef extract_allowed_actions(policy_json):\n    \"\"\"Parse AWS IAM policy JSON and return a list of all allowed actions.\"\"\"\n    if isinstance(policy_json, str):\n        policy = json.loads(policy_json)\n    else:\n        policy = policy_json\n    \n    allowed_actions = []\n    \n    # Handle both Statement as list and single statement\n    statements = policy.get('Statement', [])\n    if not isinstance(statements, list):\n        statements = [statements]\n    \n    for statement in statements:\n        # Only process Allow statements\n        if statement.get('Effect') == 'Allow':\n            actions = statement.get('Action', [])\n            \n            # Handle both string and list formats\n            if isinstance(actions, str):\n                allowed_actions.append(actions)\n            elif isinstance(actions, list):\n                allowed_actions.extend(actions)\n    \n    return allowed_actions\n\n\nif __name__ == \"__main__\":\n    if len(sys.argv) > 1:\n        # Read from command line argument\n        policy_input = sys.argv[1]\n    else:\n        # Read from stdin\n        policy_input = sys.stdin.read()\n    \n    result = extract_allowed_actions(policy_input)\n    print(json.dumps(result))\n```",
#     "test_case": {
#       "task": "Parse an AWS IAM policy JSON and return a list of all allowed actions",
#       "format": "python"
#     },
#     "score": 3.0,
#     "reasoning": "The solution correctly implements the core parsing logic for the stated task (extracting allowed actions from Allow statements) and handles common IAM policy format variations. However, it lacks robustness with no error handling, and the interpretation of 'allowed actions' is literal rather than semantic - it doesn't address that wildcard actions like 's3:*' or 'iam:*' represent many actual actions, nor does it handle the complexity of NotAction or Deny statements which are relevant for complete IAM policy analysis. For a simple parsing task, this is adequate; for production use, additional safeguards are needed."
#   },
#   {
#     "output": "```json\n{\n  \"FunctionName\": \"my-lambda-function\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::123456789012:role/lambda-execution-role\",\n  \"Timeout\": 30,\n  \"Handler\": \"index.handler\",\n  \"MemorySize\": 128,\n  \"Description\": \"Basic Lambda function configuration\"\n}\n```",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function with basic settings (function name, runtime, role ARN, timeout)",
#       "format": "json"
#     },
#     "score": 3.5,
#     "reasoning": "The solution successfully addresses the core task with a valid AWS Lambda configuration containing all four required parameters. The JSON is properly formatted and uses current best practices. However, it extends beyond requirements with extra fields and lacks clear indication that values are placeholders. The solution would benefit from being more minimal per the task scope and including clearer guidance for users to substitute their own values."
#   }
# ]
