# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text.strip())

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only Python, JSON or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
import re 
import ast 

def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0

def validate_python(text):
    try: 
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0 

def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10 
    except re.error:
        return 0 


def grade_syntax(response,test_case):
    format = test_case["format"]
    
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Step 2 
# Create a function run_test_case

def run_test_case(test_case):
    """
    Calls run_prompt, then grade the results 
    """
    output = run_prompt(test_case)

    grade = grade_by_model(test_case, output)

    # Changed from score to model_score
    model_score = grade["score"]
    reasoning = grade["reasoning"]

    syntax_score = grade_syntax(output,test_case)

    score = (model_score + syntax_score) / 2 

    return {
        "output":output,
        "test_case":test_case,
        "score": score,
        "reasoning":reasoning
    }

# %%
from statistics import mean 

def run_eval(dataset):

    results = []

    for test_case in dataset:
        result = run_test_case(test_case)

        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"average score: {average_score}")
    
    return results

# %%
with open ("dataset.json","r") as f:
    dataset = json.load(f)

    results = run_eval(dataset)
# Out:
# average score: 5.166666666666667

# %%
print(json.dumps(results,indent=2))
# Out:
# [
#   {
#     "output": "```python\nimport re\n\ndef extract_s3_bucket(s3_uri):\n    match = re.match(r's3://([^/]+)', s3_uri)\n    return match.group(1) if match else None\n```\n\nOr as a pure regex:\n\n```regex\ns3://([^/]+)\n```\n\nOr as JSON (regex pattern):\n\n```json\n{\n  \"pattern\": \"s3://([^/]+)\",\n  \"capture_group\": 1\n}\n```",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (e.g., 's3://my-bucket/path/to/file.txt') and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly solves the core task with an appropriate regex pattern and safe null handling. However, it lacks robustness in input validation and documentation. The regex pattern itself is sound and will properly extract bucket names from standard S3 URIs. The main concerns are defensive programming practices and maintainability rather than correctness."
#   },
#   {
#     "output": "```json\n{\n  \"FunctionName\": \"my-lambda-function\",\n  \"Runtime\": \"python3.11\",\n  \"Timeout\": 30,\n  \"MemorySize\": 256\n}\n```",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that specifies the function name, runtime (Python 3.11), timeout (30 seconds), and memory size (256 MB)",
#       "format": "json"
#     },
#     "score": 3.5,
#     "reasoning": "The solution successfully addresses the core task requirements by providing a valid JSON configuration with the four specified attributes in correct AWS format. However, it omits essential fields required for a functional Lambda deployment (particularly the IAM Role ARN), which limits its real-world applicability. The solution is technically correct for the stated requirements but incomplete for practical use."
#   },
#   {
#     "output": "\n```python\nimport json\nimport re\nfrom typing import Any\n\n\ndef extract_iam_actions(policy_json: str) -> list[str]:\n    \"\"\"\n    Extract all IAM actions from an AWS IAM policy JSON string.\n    \n    Args:\n        policy_json: AWS IAM policy as a JSON string\n        \n    Returns:\n        List of all actions permitted in the policy\n    \"\"\"\n    try:\n        policy = json.loads(policy_json)\n    except json.JSONDecodeError:\n        return []\n    \n    actions = []\n    \n    def extract_actions_recursive(obj: Any) -> None:\n        if isinstance(obj, dict):\n            if \"Action\" in obj:\n                action_value = obj[\"Action\"]\n                if isinstance(action_value, str):\n                    actions.append(action_value)\n                elif isinstance(action_value, list):\n                    actions.extend(action_value)\n            \n            for value in obj.values():\n                extract_actions_recursive(value)\n        elif isinstance(obj, list):\n            for item in obj:\n                extract_actions_recursive(item)\n    \n    extract_actions_recursive(policy)\n    \n    return actions\n\n\nif __name__ == \"__main__\":\n    test_policy = \"\"\"\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": [\n                    \"s3:GetObject\",\n                    \"s3:PutObject\"\n                ],\n                \"Resource\": \"arn:aws:s3:::my-bucket/*\"\n            },\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"dynamodb:Query\",\n                \"Resource\": \"arn:aws:dynamodb:us-east-1:123456789012:table/my-table\"\n            }\n        ]\n    }\n    \"\"\"\n    \n    result = extract_iam_actions(test_policy)\n    print(result)\n```",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS IAM policy JSON string and returns a list of all the actions (e.g., 's3:GetObject') permitted in the policy",
#       "format": "python"
#     },
#     "score": 3.5,
#     "reasoning": "The solution correctly solves the core requirement of extracting action strings from IAM policy JSON. The recursive approach is sound and handles the test cases well. However, it's a somewhat literal interpretation that doesn't address edge cases like wildcard patterns, duplicates, or the NotAction field. The implementation is clean and functional but could be more complete for production use. The unused `re` import also suggests incomplete development."
#   }
# ]
